# %% [markdown]
# <a href="https://colab.research.google.com/github/slmorettiUM/BTE320-In-Class-Assignments/blob/main/In_Class_Assignments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sales = float(input("enter sales ($): "))

cogs = 0.4 * sales
gross_profit = sales - cogs

print(f"Sales: {sales}$")
print(f"Cost of Goods sold: {cogs}$")
print(f"Gross profit: {gross_profit}$")

tax_rate = .065
taxes = (gross_profit * tax_rate)
net_income = gross_profit - taxes

print(f"Sales tax: {taxes}$")
print(f"Net income: {net_income}$")
# Out:
# enter sales ($): 45000
# Sales: 45000.0$
# Cost of Goods sold: 18000.0$
# Gross profit: 27000.0$
# Sales tax: 1755.0$
# Net income: 25245.0$

# %%
num1 = float(input("enter first number: "))
num2 = float(input("enter second number: "))
op = input("Choose Numerical Operator (+, -, *, /, //, **, %): ")

if op == '+':
  print(f"{num1} + {num2} = {num1 + num2}")
elif op == '-':
  print(f"{num1} - {num2} = {num1 - num2}")
elif op == '*':
  print(f"{num1} * {num2} = {num1 * num2}")
elif op == '/':
  print(f"{num1} / {num2} = {num1 / num2}")
elif op == '//':
  print(f"{num1} // {num2} = {num1 // num2}")
elif op == '**':
  print(f"{num1} ** {num2} = {num1 ** num2}")
elif op == '%':
  print(f"{num1} % {num2} = {num1 % num2}")
else:
  print("Invalid Operation")
# Out:
# enter first number: 45
# enter second number: 8
# Choose Numerical Operator (+, -, *, /, //, **, %): **
# 45.0 ** 8.0 = 16815125390625.0

# %%
base_fee = 5.0
hourly_rate = 2.50

for hours in range(0,9):
  total_fee = base_fee + (hourly_rate * hours)
  if total_fee < 10.0:
    total_fee = 10.0
  elif total_fee > 20.0:
    total_fee = 20.0
  print(f"{hours} ${total_fee}")
# Out:
# 0 $10.0
# 1 $10.0
# 2 $10.0
# 3 $12.5
# 4 $15.0
# 5 $17.5
# 6 $20.0
# 7 $20.0
# 8 $20.0
